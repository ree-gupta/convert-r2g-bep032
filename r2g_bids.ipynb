# %%
import odml
import pandas as pd

monkeyL_metadata_odml = 'multielectrode_grasp/datasets_blackrock/l101210-001.odml'
monkeyN_metadata_odml = 'multielectrode_grasp/datasets_blackrock/i140703-001.odml'

monkeyL_metadata = odml.load(monkeyL_metadata_odml)
monkeyN_metadata = odml.load(monkeyN_metadata_odml)
# Out:
# warning[None:17:<{http://www.w3.org/1999/xsl/transform}stylesheet>]: Invalid element <{http://www.w3.org/1999/xsl/transform}stylesheet> inside <odML> tag
#  (line 17)
# warning[None:17:<{http://www.w3.org/1999/xsl/transform}stylesheet>]: Invalid element <{http://www.w3.org/1999/xsl/transform}stylesheet> in odML document section <odML>  (line 17)
# ...
# Validation found 0 errors and 3 warnings in 0 Sections and 3 Properties.
# warning[None:17:<{http://www.w3.org/1999/xsl/transform}stylesheet>]: Invalid element <{http://www.w3.org/1999/xsl/transform}stylesheet> inside <odML> tag
#  (line 17)
# warning[None:17:<{http://www.w3.org/1999/xsl/transform}stylesheet>]: Invalid element <{http://www.w3.org/1999/xsl/transform}stylesheet> in odML document section <odML>  (line 17)

# %%
odml_keys = ['Identifier', 'Species', 'Gender', 'Birthday', 'ActiveHand', 'TrivialName', 'GivenName', 'Disabilities', 'Character']

# %%
monkeyL_metadata['Setup'].pprint()
# Out:
#  Setup [setup]
#     |- Location: ['Inst. de Neurosciences Cognitives de la ...  Aix Marseille Univ., Marseille, France']
#     |- DAQSystem: ['Cerebus']
#    Apparatus [setup]
#       |- Creator: ['Thomas Brochier']
#       |- Maintainer: ['Thomas Brochier']
#      NIConnectorBlock [setup]
#        [...]
#      ADConverterCard [setup]
#        [...]
#      StartSwitch [setup]
#        [...]
#      TargetObject [setup]
#        [...]
#      CueSystem [setup]
#        [...]
#      RewardSystem [setup]
#        [...]

# %%
monkeyL_metadata.sections['Setup'].sections['Apparatus'].pprint()
# Out:
#  Apparatus [setup]
#     |- Creator: ['Thomas Brochier']
#     |- Maintainer: ['Thomas Brochier']
#    NIConnectorBlock [setup]
#       |- Type: ['input/output connector block']
#       |- Manufacturer: ['NI, National Instruments Corporation, Au ... truments Corporation, Austin, Texas, USA']
#       |- Function: ['used to connect devices of the apparat ... mputer and the Neural Signal Processor']
#    ADConverterCard [setup]
#       |- Type: ['NI 6023E']
#       |- Manufacturer: ['NI, National Instruments Corporation, Au ... truments Corporation, Austin, Texas, USA']
#       |- Function: ['used as analog/digital converter for t ... trol the reward pump to digital events']
#    StartSwitch [setup]
#       |- Function: ['activates the internal initiation of t ... e onset of the reach-to-grasp movement']
#       |- Type: ['table switch']
#       |- SignalType: ['analog']
#       |- TrialEvents: ['SR']
#       |- SamplingRate: [30000]Hz
#       |- ConnectedTo: ['NI connector block']
# ...

# %%
monkeyL_metadata.sections['Setup'].sections['Apparatus'].properties
# Out:
# [Property: {name = Creator}, Property: {name = Maintainer}]

# %%
monkeyL_metadata.sections['UtahArray'].pprint()
# Out:
#  UtahArray [setup/daq/hardware]
#     |- Owner: ['RIKEN-BSI, Japan']
#     |- SerialNo: ['1025-0503']
#     |- Manufacturer: ['Blackrock Microsystems']
#     |- WiresMaterial: ['Pt/Au']
#     |- WiresDiameter: [25.0]um
#     |- WiresLength: [40.0]mm
#    Connector [setup/daq/hardware]
#       |- Style: ['CerePort']
#       |- Height: [16.5]mm
#       |- DiameterBase: [19.0]mm
#       |- DiameterBody: [11.0]mm
#       |- ImplantType: ['chronic']
#       |- SkullMount: ['bone screws']
#    Array [setup/daq/hardware]
#       |- GridCount: [1]
#       |- ReferenceCount: [2]
#       |- GroundCount: [1]
#       |- ElectrodeCount: [100]
#       |- ActiveElectrodeCount: [96]
#       |- UsedElectrodeCount: [96]
#      Grid_01 [setup/daq/hardware]
#        [...]
#      Electrode_001 [setup/daq/hardware]
#        [...]
#      Electrode_002 [setup/daq/hardware]
#        [...]
#      Electrode_003 [setup/daq/hardware]
#        [...]
#      Electrode_004 [setup/daq/hardware]
#        [...]
# ...

# %%
monkeyN_metadata.sections['UtahArray']['Array'].pprint()
# Out:
#  Array [setup/daq/hardware]
#     |- GridCount: [1]
#     |- ReferenceCount: [2]
#     |- GroundCount: [1]
#     |- ElectrodeCount: [100]
#     |- ActiveElectrodeCount: [96]
#     |- UsedElectrodeCount: [96]
#    Grid_01 [setup/daq/hardware]
#       |- ID: [1]
#       |- ElectrodeGeometry: ['flat']
#       |- ElectrodeMetal: ['iridium oxide']
#       |- ElectrodePitch: [400.0]um
#       |- Insulation: ['Parylene-C']
#       |- GridRows: [10]
#       |- GridColumns: [10]
#       |- GridWidth: [4.0]mm
#       |- GridLength: [4.0]mm
#       |- ElectrodeCount: [100]
#       |- ActiveElectrodeCount: [96]
#    Electrode_001 [setup/daq/hardware]
#       |- ID: [1]
#       |- GridID: [1]
#       |- BankID: [1]
#       |- PinID: [1]
#       |- ConnectorAlignedID: [93]
#       |- Impedance: [73.0]kΩ
#       |- Length: [1.5]mm
#      OfflineSpikeSorting [setup/daq/preprocessing]
#        [...]
#    Electrode_002 [setup/daq/hardware]
#       |- ID: [2]
#       |- GridID: [1]
# ...

# %%
monkeyL_metadata['UtahArray'].sections

# %%
probes_tsv_header = ['probe_id', 'type', 'x', 'y', 'z', 'manufacturer', 'device_serial_number', 'contact_count', 
                     'width', 'height', 'depth', 'dimension_unit', '']
